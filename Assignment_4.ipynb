# %% [markdown]
# <a href="https://colab.research.google.com/github/royaltyfavs379/AI-and-Data-Science-Class-of-2026/blob/main/Assignment_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
name=input('enter student name;')
age=int(input('enter student age;'))
marks=float(input('enter student marks;'))
print(f'{name,age,marks}')
print(f'{name} added successfully')
name=input('enter student name;')
age=int(input('enter student age;'))
marks=float(input('enter student marks;'))
print(f"{name,age,marks}")
print(f'{name} added successfully')
name=input('enter student name;')
age=int(input('enter student age;'))
marks=float(input('enter student marks;'))
print(f'{name,age,marks}')
print(f'{name} added successfully')
name=input('enter student name;')
age=int(input('enter student age;'))
marks=float(input('enter student marks;'))
print(f'{name,age,marks}')
print(f'{name} added successfully')
# Out:
# enter student name;fav
# enter student age;45
# enter student marks;76
# ('fav', 45, 76.0)
# fav added successfully
# enter student name;hans
# enter student age;78
# enter student marks;65
# ('hans', 78, 65.0)
# hans added successfully
# enter student name;kill
# enter student age;90
# enter student marks;98
# ('kill', 90, 98.0)
# kill added successfully
# enter student name;poll
# enter student age;56
# enter student marks;67
# ('poll', 56, 67.0)
# poll added successfully
