# %% [markdown]
# <a href="https://colab.research.google.com/github/royaltyfavs379/AI-and-Data-Science-Class-of-2026/blob/main/Assignment4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
Assignment4

# %% [markdown]
# def add student(student)

# %%
name=input('enter student name:')
age=int(input('enter student age:'))
marks=float(input('enter student marks:'))
student=[f'name,age,marks']
print('student added successfully')
name=input('enter student name:')
age=int(input('enter student age:'))
marks=float(input('enter student marks:'))
student=[f'"name",age,marks']
print('{name}added successfully')
name=input('enter student name:')
age=int(input('enter student marks:'))
marks=float(input('enter student marks:'))
student=[f'"name",age,marks']
print('{name}added successfully')
name=input('enter student name:')
age=int(input('enter student age:'))
marks=float(input('enter student marks:'))
student=[f'name,age,marks']
print('{name}added successfully')
name=input('enter student name:')
age=int(input('enter student age:'))
marks=float(input('enter student marks:'))
student=[f'"name",age,marks']
print('{name}added successfully')
# Out:
# enter student name:fav
# enter student age:14
# enter student marks:65
# student added successfully
